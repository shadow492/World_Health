# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

BASE_PATH = "/Users/dhairyabhatt/code_dir/Data analytics projects/world_health/data"
OUTPUT_PATH = os.path.join(BASE_PATH, "phase3_outputs")

# %%
# Cell 1 — Load & Inspect Q25 Dataset

q25 = pd.read_csv(os.path.join(OUTPUT_PATH, "q25_pharma_doctor_ratio.csv"))

print(q25.shape)
print(q25.columns.tolist())
print(q25.dtypes)

# Normalize the expenditure column name in case it wasn't renamed during Phase 3 construction
if "value" in q25.columns and "catex_pct" not in q25.columns:
    q25 = q25.rename(columns={"value": "catex_pct"})

q25.head()
# Out:
# (149, 5)
# ['country', 'pharm_per_10k', 'doc_per_10k', 'pharm_doc_ratio', 'catex_pct']
# country                str
# pharm_per_10k      float64
# doc_per_10k        float64
# pharm_doc_ratio    float64
# catex_pct          float64
# dtype: object
#       country  pharm_per_10k  doc_per_10k  pharm_doc_ratio  catex_pct
# 0       Benin           0.27         0.79         0.341772      10.92
# 1  Mozambique           0.10         0.84         0.119048       1.61
# 2     Namibia           2.44         4.18         0.583732       1.22
# 3       Nepal           3.95         7.49         0.527370      10.71
# 4      France          10.64        32.67         0.325681       1.42

# %%
# Cell 2 — Drop Rows With Missing Ratio (zero-doctor countries set to NaN in Phase 3)

q25_clean = q25.dropna(subset=["pharm_doc_ratio", "catex_pct"]).copy()
print(f"Countries available for correlation: {len(q25_clean)}")
# Out:
# Countries available for correlation: 149

# %%
# Cell 3 — Scatter Plot: Pharmacist:Doctor Ratio vs Catastrophic Expenditure

plt.figure(figsize=(9, 7))
plt.scatter(q25_clean["pharm_doc_ratio"], q25_clean["catex_pct"], alpha=0.6)
plt.xlabel("Pharmacist-to-Doctor Ratio")
plt.ylabel("Catastrophic Health Expenditure (%)")
plt.title("Pharmacist:Doctor Ratio vs Catastrophic Health Expenditure")
plt.grid(alpha=0.3)
plt.show()

# %%
# !pip3 install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.18.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: numpy<2.8,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scipy) (2.4.6)
# Downloading scipy-1.18.0-cp313-cp313-macosx_14_0_arm64.whl (20.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.4/20.4 MB 7.0 MB/s  0:00:02m0:00:0100:01
# Installing collected packages: scipy
# Successfully installed scipy-1.18.0
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip

# %%
# Cell 4 — Correlation Strength (Pearson + Spearman, since ratio may be skewed/non-linear)
import scipy

pearson_r = q25_clean["pharm_doc_ratio"].corr(q25_clean["catex_pct"], method="pearson")
spearman_r = q25_clean["pharm_doc_ratio"].corr(q25_clean["catex_pct"], method="spearman")

print(f"Pearson correlation:  {pearson_r:.3f}")
print(f"Spearman correlation: {spearman_r:.3f}")
# Out:
# Pearson correlation:  0.118
# Spearman correlation: 0.039

# %%
# Cell 5 — Median Split: High-Ratio vs Low-Ratio Countries

median_ratio = q25_clean["pharm_doc_ratio"].median()
q25_clean["ratio_group"] = np.where(
    q25_clean["pharm_doc_ratio"] >= median_ratio, "High ratio", "Low ratio"
)

group_comparison = q25_clean.groupby("ratio_group")["catex_pct"].agg(["mean", "median", "count"])
group_comparison
# Out:
#                  mean  median  count
# ratio_group
# High ratio   9.655333   6.400     75
# Low ratio    8.011622   6.645     74

# %%
# Cell 6 — Plot Group Comparison

plt.figure(figsize=(6, 6))
plt.bar(group_comparison.index, group_comparison["mean"], color=["firebrick", "steelblue"])
plt.ylabel("Mean Catastrophic Health Expenditure (%)")
plt.title("Catastrophic Expenditure: High vs Low Pharmacist:Doctor Ratio Countries")
plt.grid(axis="y", alpha=0.3)
plt.show()

# %%
# Cell 7 — Top 10 Countries by Pharmacist:Doctor Ratio

top10_ratio = q25_clean.sort_values("pharm_doc_ratio", ascending=False).head(10)
top10_ratio[["country", "pharm_per_10k", "doc_per_10k", "pharm_doc_ratio", "catex_pct"]]
# Out:
#                               country  pharm_per_10k  doc_per_10k  \
# 126                          Djibouti           2.34         2.24
# 20                              India           8.87         8.57
# 13                              Egypt           4.57         4.52
# 116       United Republic of Tanzania           0.14         0.14
# 95               Syrian Arab Republic          10.66        12.87
# 98                              Japan          18.02        24.12
# 128                           Albania           8.41        12.16
# 60                             Jordan          16.01        23.24
# 34                           Thailand           5.53         8.05
# 53   Lao People's Democratic Republic           2.46         3.73
#
#      pharm_doc_ratio  catex_pct
# 126         1.044643       1.14
# 20          1.035006      17.33
# 13          1.011062      26.20
# 116         1.000000       3.79
# 95          0.828283       6.88
# 98          0.747098       4.36
# 128         0.691612      16.72
# 60          0.688898       1.72
# 34          0.686957       2.22
# 53          0.659517       2.98

# %%
# Cell 8 — Plot Top 10 Countries: Ratio vs Their Catastrophic Expenditure

fig, ax1 = plt.subplots(figsize=(11, 6))

x = np.arange(len(top10_ratio))
ax1.bar(x, top10_ratio["pharm_doc_ratio"], color="steelblue", label="Pharmacist:Doctor Ratio")
ax1.set_ylabel("Pharmacist:Doctor Ratio", color="steelblue")
ax1.set_xticks(x)
ax1.set_xticklabels(top10_ratio["country"], rotation=45, ha="right")

ax2 = ax1.twinx()
ax2.plot(x, top10_ratio["catex_pct"], color="firebrick", marker="o", label="Catastrophic Expenditure (%)")
ax2.set_ylabel("Catastrophic Health Expenditure (%)", color="firebrick")

plt.title("Top 10 Countries by Pharmacist:Doctor Ratio — vs Catastrophic Expenditure")
fig.tight_layout()
plt.show()
